# %% [markdown]
# # Import packages

# %%
import torch
import torch.nn as nn
import torchdiffeq
from torchdiffeq import odeint
from xitorch.interpolate import Interp1D
from scipy.interpolate import interp1d
from matplotlib import pyplot as plt

torch.set_default_dtype(torch.float)

# %% [markdown]
# # Define classes for parameter-container and sequence generator

# %%
"""
Class RateStateParams, manages data of rate-and-state friction with flash-heating effect, contains 
    Data:
        fr: Reference friction coefficient
        a: Rate-and-state parameter a
        b: Rate-and-state parameter b
        DRS: Characteristic slip distance
        Vw: Flash-heating slip rate
        fw: Flash-heating friction coefficient
        
"""
class RateStateParams:
    # Constructor
    def __init__(self, fr = 0.6, Vr = 1.e-6, a = 0.016, b = 0.011, DRS = 1.e-6, Vw = 1.0e6, fw = 0.2):
        self.fr = fr
        self.Vr = Vr
        self.a = a
        self.b = b
        self.DRS = DRS
        self.Vw = Vw
        self.fw = fw
        
    # Output the information of this class
    def print_info(self):
        print("-" * 20, " Rate-and-state parameters ", "-"*20)
        print('fr:       ', self.fr)
        print('a:        ', self.a)
        print('b:        ', self.b)
        print('Vr:       ', self.Vr)
        print('DRS:      ', self.DRS)
        print('Vw:       ', self.Vw)
        print('fw:       ', self.fw)

# %%
"""
Class TimeSequenceGen, container for a Generated time sequence containing 
    Data:
        t [number of time points]: Tensor for time stamps, prescribed
        N [number of time points]: Tensor for normal stress, prescribed
        Ds [number of time points]: Tensor for slip rate, prescribed
        s [number of time points]: Tensor for slip, prescribed
        theta [number of hidden variables, number of time points]: Tensor for hidden variables, computed
        params : Class for parameters
   
    Method:
        __init__ : Constructor
        DthetaDt : Evolution function for hidden variables theta
        calTau : Calculate the function of shear stress Tau
        
"""
class TimeSequenceGen:
    # Constructor
    def __init__(self, t, N, Ds, params, regularizedFrictionLaw):
        # Load the parameters
        self.t = t
        self.N = N
        self.Ds = Ds
        self.s = torch.zeros(Ds.shape, dtype = torch.float64)
        self.s[:, 1:] = torch.cumulative_trapezoid(Ds, x = t)
        self.params = params
        self.regFlag = regularizedFrictionLaw
        
        # Calculate theta history
        self.theta = torch.zeros(Ds.shape, dtype = torch.float64)
        
        # Compute the interpolation for slip rate Ds
        self.t_temp = torch.concat([self.t, torch.tensor([self.t[-1] + 1.0])], 0)
        self.Ds_temp = torch.concat([self.Ds, self.Ds[:, -1].reshape([-1, 1])], 1)
        self.DsAtT = interp1d(self.t_temp, self.Ds_temp, kind="cubic")
        
        # Evolve theta(t)
        self.theta = torch.transpose(self.calTheta(), 0, 1)

        # Finish computing tau
        self.tau = self.calTau()
    
    # Function DthetaDt, defines DthetaDt as a function of temporally local values
    def DthetaDt(self, t, theta):
        # print('t = ', t)
        DthetaDt = 1. - (torch.tensor(self.DsAtT(t)) * theta / self.params.DRS)
        return DthetaDt
    
    # Function calTau, calculates shear traction tau, suingregularized rate-and-state formulation
    def calTau(self):
        # Set aliases for rate-and-state parameters
        a = self.params.a
        b = self.params.b
        Vr = self.params.Vr
        DRS = self.params.DRS
        fr = self.params.fr
        if self.regFlag:
            tau = self.N * a * torch.asinh(
                   self.Ds / 2. / Vr * torch.exp((fr + b * torch.log(Vr * self.theta / DRS)) / a)
                   )
        else :
            tau = self.N * (fr + a * torch.log(self.Ds / Vr) + b * (self.theta * Vr / DRS))
            
        return tau
    
    # Calculate theta using s(t), Ds(t), theta(t) and params
    def calTheta(self, theta0 = 1.0):
        theta = odeint(self.DthetaDt, theta0 * torch.ones(self.Ds.shape[0], dtype = torch.float64), self.t, 
                       rtol = 1.e-10, atol = 1.e-12, method = 'dopri8')
        return theta

# %% [markdown]
# # Generate training sequences in parallel

# %%
# Import joblibs
from joblib import Parallel, delayed, effective_n_jobs
print('Number of workers available: ', effective_n_jobs(-1))
# Out:
# Number of workers available:  36

# %%
"""
Function generateVAndN, generate V and N sequences. 
    Inputs: #-----------------------------------------------------------------------------------------
        N_seq: Number of sequences to be generated
        N_grid_points: Number of grid points in [0, T]
        n_Fourier: Number of Fourier terms in the generating functions
        T: Maximum time
        target_logV_range: The range of logV
        target_N_range: The range of normal stress
        
    Outputs: #----------------------------------------------------------------------------------------
        NAll [N_seq, N_grid_points]: Generated sample sequences of N(t)
        VAll [N_seq, N_grid_points]: Generated sample sequences of V(t)
        
"""

def generateTVAndN(N_seq = 10_000, 
                  N_grid_points = 1_000, 
                  n_Fourier = 16, 
                  T = 100.e-6, 
                  target_logV_range = [-15., 2.], 
                  target_N_range = [1., 12.]):
    
    # Generate time grid (uniform)
    t = torch.linspace(0., T, N_grid_points, dtype = torch.float64)
    
    # Pre-calculate sin(k pi/T t) and cos(k pi/T t)
    K = torch.linspace(0, n_Fourier - 1, n_Fourier, dtype = torch.float64)
    kPitOverT = K.reshape([-1, 1]) * torch.pi / T * t


    # Generate N(t) sequences in MPa, N_seq times
    NfSin = (torch.rand([N_seq, n_Fourier], dtype = torch.float64) - 0.5) * 5.
    NfCos = (torch.rand([N_seq, n_Fourier], dtype = torch.float64) - 0.5) * 5.

    # All N_seq normal tractions
    NAll = torch.matmul(NfSin, torch.sin(kPitOverT)) + torch.matmul(NfCos, torch.cos(kPitOverT))

    # Generate logV(t) sequences in m/s, N_seq times
    VfSin = (torch.rand([N_seq, n_Fourier], dtype = torch.float64) - 0.5) * 10.
    VfCos = (torch.rand([N_seq, n_Fourier], dtype = torch.float64) - 0.5) * 10.

    # All N_seq normal tractions
    VAll = torch.matmul(VfSin, torch.sin(kPitOverT)) + torch.matmul(VfCos, torch.cos(kPitOverT)) - 7.


    ## Rescale VAll, NAll into target range
    # ---------------------------------------------------------------------------------------------------------
    minVAll = torch.min(VAll, axis=1).values
    maxVAll = torch.max(VAll, axis=1).values
    VAll = VAll / (maxVAll - minVAll).reshape([-1, 1]) * (target_logV_range[1] - target_logV_range[0]) 
    # VAll -= (torch.min(VAll, axis=1).values - target_logV_range[0]).reshape([-1, 1])
    # VAll = torch.clip(VAll, min = target_logV_range[0], max = target_logV_range[1])
    print('Min, max of logV: ', torch.min(VAll).item(), torch.max(VAll).item())
    VAll = torch.pow(10., VAll)

    # NAll = torch.clip(NAll, min = target_N_range[0], max = target_N_range[1])
    minNAll = torch.min(NAll, axis=1).values
    maxNAll = torch.max(NAll, axis=1).values
    NAll = NAll / (maxNAll - minNAll).reshape([-1, 1]) * (target_N_range[1] - target_N_range[0]) 
    NAll -= (torch.min(NAll, axis=1).values - target_N_range[0]).reshape([-1, 1])

    print('Min, max of N: ', torch.min(NAll).item(), torch.max(NAll).item())

    return t, NAll, VAll

"""
Function generateVAndNPiecewiseConst, generate V and N sequences. 
    Inputs: #-----------------------------------------------------------------------------------------
        N_seq: Number of sequences to be generated
        N_grid_points: Number of grid points in [0, T]
        n_Fourier: Number of Fourier terms in the generating functions
        T: Maximum time
        target_logV_range: The range of logV
        target_N_range: The range of normal stress
        
    Outputs: #----------------------------------------------------------------------------------------
        NAll [N_seq, N_grid_points]: Generated sample sequences of N(t)
        VAll [N_seq, N_grid_points]: Generated sample sequences of V(t)
        
"""

def generateTVAndNPiecewiseConst(N_seq = 10_000, 
                  N_grid_points = 1_000, 
                  n_intervals = 16, 
                  T = 100.e-6, 
                  target_logV_range = [-15., 2.], 
                  target_N_range = [1., 12.]):
    
    # Generate time grid (uniform)
    t = torch.linspace(0., T, N_grid_points, dtype = torch.float64)
    
    # Pre-calculate sin(k pi/T t) and cos(k pi/T t)
    K = torch.linspace(0, n_Fourier - 1, n_Fourier, dtype = torch.float64)
    kPitOverT = K.reshape([-1, 1]) * torch.pi / T * t


    # Generate N(t) sequences in MPa, N_seq times
    NfSin = (torch.rand([N_seq, n_Fourier], dtype = torch.float64) - 0.5) * 5.
    NfCos = (torch.rand([N_seq, n_Fourier], dtype = torch.float64) - 0.5) * 5.

    # All N_seq normal tractions
    NAll = torch.matmul(NfSin, torch.sin(kPitOverT)) + torch.matmul(NfCos, torch.cos(kPitOverT))

    # Generate logV(t) sequences in m/s, N_seq times
    VLevels = (torch.rand([N_seq, n_intervals]) - (0.5 - (target_logV_range[1] + target_logV_range[0]) / 2)) \
              * (target_logV_range[1] - target_logV_range[0])
    
    VPoints = torch.rand([N_seq, n_intervals - 1]) * T 
    
    # All N_seq normal tractions
    VAll = torch.matmul(VfSin, torch.sin(kPitOverT)) + torch.matmul(VfCos, torch.cos(kPitOverT)) - 7.


    ## Rescale VAll, NAll into target range
    # ---------------------------------------------------------------------------------------------------------
    minVAll = torch.min(VAll, axis=1).values
    maxVAll = torch.max(VAll, axis=1).values
    VAll = VAll / (maxVAll - minVAll).reshape([-1, 1]) * (target_logV_range[1] - target_logV_range[0]) 
    # VAll -= (torch.min(VAll, axis=1).values - target_logV_range[0]).reshape([-1, 1])
    # VAll = torch.clip(VAll, min = target_logV_range[0], max = target_logV_range[1])
    print('Min, max of logV: ', torch.min(VAll).item(), torch.max(VAll).item())
    VAll = torch.pow(10., VAll)

    # NAll = torch.clip(NAll, min = target_N_range[0], max = target_N_range[1])
    minNAll = torch.min(NAll, axis=1).values
    maxNAll = torch.max(NAll, axis=1).values
    NAll = NAll / (maxNAll - minNAll).reshape([-1, 1]) * (target_N_range[1] - target_N_range[0]) 
    NAll -= (torch.min(NAll, axis=1).values - target_N_range[0]).reshape([-1, 1])

    print('Min, max of N: ', torch.min(NAll).item(), torch.max(NAll).item())

    return t, NAll, VAll

# Define the function as a wrapper for generate tau and theta
def getSTauAndTheta(t, N, V, params, regularizedFrictionLaw = True):
    mySeq = TimeSequenceGen(t, N, V, params, regularizedFrictionLaw)
    return mySeq.s, mySeq.tau, mySeq.theta

# %%
import time
# Generate the sequences
filename = "./data/sequence3.pt"
N_samples = 10_000
N_gridPts = 1_000

t, NAll, VAll = generateTVAndN(N_seq = N_samples, N_grid_points = N_gridPts)
RSparams = RateStateParams()
RSparams.print_info()

# Compute tau and theta
st_time = time.time()
sAll, tauAll, thetaAll = getSTauAndTheta(t, NAll, VAll, RSparams)
timeConsumed = time.time() - st_time
print('Time consumed (single core): ', timeConsumed, ' s')

# Save to file
seqObj = {'S' : sAll, 'N' : NAll, 'V' : VAll, 'tau' : tauAll, 'theta' : thetaAll, 't' : t}
torch.save(seqObj, filename)
# Out:
# Min, max of logV:  -15.0 2.0
# Min, max of N:  0.9999999999999991 12.000000000000004
# --------------------  Rate-and-state parameters  --------------------
# fr:        0.6
# a:         0.016
# b:         0.011
# Vr:        1e-06
# DRS:       1e-06
# Vw:        1000000.0
# fw:        0.2
# Time consumed (single core):  431.0603802204132  s

# %% [markdown]
# # Generate sequences using non-regularized rate-and-state law

# %% [raw]
# # Load from file
# import time
# filename = "./data/sequence3.pt"
# loaded = torch.load(filename)
# tauAll = loaded['tau']
# NAll = loaded['N']
# VAll = loaded['V']
# sAll = loaded['S']
# thetaAll = loaded['theta']
# t = loaded['t']
# RSparams = RateStateParams()
#
# # Compute tau and theta
# st_time = time.time()
# sAllUnReg, tauAllUnReg, thetaAllUnReg = getSTauAndTheta(t, NAll, VAll, RSparams, False)
# timeConsumed = time.time() - st_time
# print('Time consumed (single core): ', timeConsumed, ' s')
#
# # Save the unregularized sequences to file
# seqObj = {'S' : sAll, 'N' : NAll, 'V' : VAll, 'tau' : tauAll, 'theta' : thetaAll,
#           'SUnReg' : sAllUnReg, 'tauUnReg' : tauAllUnReg, 'thetaAllUnReg' : thetaAllUnReg, 't' : t}
#
# torch.save(seqObj, filename)

# %%
# Load un-regularized sequences
filename = "./data/sequence3.pt"
loaded = torch.load(filename)
tauAll = loaded['tauUnReg']
NAll = loaded['N']
VAll = loaded['V']
sAll = loaded['SUnReg']
thetaAll = loaded['thetaAllUnReg']
t = loaded['t']
RSparams = RateStateParams()

# %%
# Plot Sequence of V(t) and N(t) given sample-index
sample_idx = 5000
f, axs = plt.subplots(2, 2, figsize = (15, 15))

# Plot V(t)
axs[0][0].semilogy(1e6 * t, VAll[sample_idx, :], linewidth=2.0)
axs[0][0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0][0].set_ylabel('Slip rate $V(t)\  \mathrm{[m/s]}$', fontsize=20)
axs[0][0].set_ylim([1e-15, 1e2])
axs[0][0].grid()

# Plot N(t)
axs[0][1].plot(1e6 * t, NAll[sample_idx, :], linewidth=2.0)
axs[0][1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0][1].set_ylabel('Normal traction $N(t)\ \mathrm{[MPa]}$', fontsize=20)
axs[0][1].set_ylim([0, 15])
axs[0][1].grid()
                
# Plot theta(t)
axs[1][0].semilogy(1e6 * t, thetaAll[sample_idx, :], linewidth=3.0)
axs[1][0].semilogy(1e6 * t, RSparams.DRS / VAll[sample_idx, :], linewidth=2.0)
axs[1][0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1][0].set_ylabel('State Variable $\\theta(t)\ \mathrm{[s]}$', fontsize=20)
axs[1][0].legend(['True', 'Steady state'], loc='best', fontsize=20)
axs[1][0].grid()
                
# Plot \tau(t)
axs[1][1].plot(1e6 * t, tauAll[sample_idx, :], linewidth=2.0)
axs[1][1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1][1].set_ylabel('Shear traction $\\tau(t)\ \mathrm{[MPa]}$', fontsize=20)
axs[1][1].grid()

f.suptitle("The " + str(sample_idx) + "th sequence", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'The 5000th sequence')

# %% [markdown]
# # RNN for training

# %%
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()

# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU is available

# %%
"""
Class RSRNN: Maps from X(t) = (N(t), V(t), S(t)) to tau(t)
   
"""
class RSRNN(nn.Module):
    
    # Constructor
    def __init__(self, input_size = 3, output_size = 1, hidden_dim = 1, n_layers = 1, isGRU = False):
        r"""
            Inputs: #-----------------------------------------------------------------------------------------
                input_size: dimension of input X(t)
                output_size: dimension of output tau(t)
                hidden_dim: dimension of hidden variables xi(t)
                n_layers: number of stacked RNN layers
        
        """
        
        # Call parent class constructor
        super(RSRNN, self).__init__()
        
        # Defining some parameters
        self.input_size = input_size
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        #Defining the layers
        # RNN Layer
        self.rnn = nn.RNN(input_size = self.input_size, 
                          hidden_size = self.hidden_dim, 
                          num_layers = n_layers, 
                          batch_first = True)
        if isGRU:
            self.rnn = nn.GRU(input_size = self.input_size, 
                              hidden_size = self.hidden_dim, 
                              num_layers = n_layers, 
                              batch_first = True)
        
        # Fully connected layers, maps from (X(t), xi(t)) to tau(t)
        self.fc = nn.Sequential(
            nn.Linear(input_size + hidden_dim, 64), 
            nn.ReLU(), 
            nn.Linear(64, 64), 
            nn.ReLU(), 
            nn.Linear(64, output_size),
        )
    
    
    # Forward evaluation function
    def forward(self, x):
        r"""
            Inputs: #-----------------------------------------------------------------------------------------
                x [batch_size, sequence_length, input_size]: A batch of input sequences X([0, t])

            Outputs: #----------------------------------------------------------------------------------------
                out [batch_size, sequence_length, output_size]: The batch of output sequences tau([0, t])
                Hs [batch_size, sequence_length, hidden_dim]: The batch of hidden variables xi([0, t]), 
                    only on the last layer if n_layers is greater than 1.
            
        """
        # Get the batch_size, x is organized as [batch_size, sequence_length, input_size]
        batch_size = x.size(0)

        # Initializing hidden state for first input using method defined below
        hidden = self.init_hidden(batch_size)

        # Passing in the input and hidden state into the model and obtaining outputs
        Hs, hidden = self.rnn(x, hidden)
        
        # Reshaping the outputs such that it can be fit into the fully connected layer
        xAndH = torch.cat([x, Hs], 2)
        # xAndH_newView = xAndH.contiguous().view(-1, self.hidden_dim + self.input_size)
        
        # Get the output from (x, H)
        out = self.fc(xAndH)
        
        return out, Hs
    
    
    # Initialize the hidden variables xi(0)
    def init_hidden(self, batch_size):
        r"""
            Inputs: #-----------------------------------------------------------------------------------------
                batch_size
                
            Outputs: #-----------------------------------------------------------------------------------------
                hidden [n_layers, batch_size, hidden_dim]: Initialized hidden 
        """
        # This method generates the first hidden state of zeros which we'll use in the forward pass
        # We'll send the tensor holding the hidden state to the device we specified earlier as well
        hidden = torch.ones([self.n_layers, batch_size, self.hidden_dim])
        return hidden

# %% [markdown]
# # Define loss functions

# %%
"""
Function AccessibleL2Loss, Calculate L2 loss in time for a sequence
    Inputs: #-----------------------------------------------------------------------------------------
        X [batch_size, n_grid_points]: A batch of predicted sequences
        X_true [batch_size, n_grid_points]: The batch of real sequences
        
    Outputs: #----------------------------------------------------------------------------------------
        L2Loss: |X - X_true|^2
        
"""
def AccessibleL2Loss(X, X_true, normalize = True):
    L2Loss = torch.sum(torch.square(X - X_true)) / X.shape[0]
    if normalize:
        L2Loss = L2Loss / X.shape[1]
    return torch.sqrt(L2Loss)

# %% [markdown]
# # Set up a training example

# %%
# Dataloader
from torch.utils.data import TensorDataset, DataLoader
logVFlag = True

# Data set contains ([N(t), V(t), S(t)]; [theta(t), tau(t)])
XAll = torch.stack([NAll, VAll, sAll], 2)

# Turn input into logV
if logVFlag:
    XAll = torch.stack([NAll, torch.log10(VAll), sAll], 2)

print('XAll shape: ', XAll.shape)

AllData = TensorDataset(
    XAll.float(),
    thetaAll.reshape([thetaAll.shape[0], thetaAll.shape[1], 1]).float(),
    tauAll.reshape([thetaAll.shape[0], thetaAll.shape[1], 1]).float(),
)

# Training-testing separation
trainSetLen = int(len(AllData) * 0.8)
testSetLen = len(AllData) - trainSetLen

# Train on multiplied data set
XAll_train = XAll[0 : trainSetLen]
thetaAll_train = thetaAll[0 : trainSetLen]
tauAll_train = tauAll[0 : trainSetLen]

# Change the duplicated ratios over N
NByN0 = [0.25, 0.5, 1., 2., 4.]
XAll_train = torch.cat([XAll_train * torch.tensor([[[x, 1., 1.]]]) for x in NByN0], 0)
thetaAll_train = torch.cat([thetaAll_train for i in range(len(NByN0))], 0)
tauAll_train = torch.cat([tauAll_train * torch.tensor(x) for x in NByN0], 0)

training_indexes = torch.randperm(XAll_train.shape[0])
XAll_train = XAll_train[training_indexes]
thetaAll_train = thetaAll_train[training_indexes]
tauAll_train = tauAll_train[training_indexes]

trainDataSet = TensorDataset(
    XAll_train.float(), 
    thetaAll_train.reshape([thetaAll_train.shape[0], thetaAll_train.shape[1], 1]),
    tauAll_train.reshape([thetaAll_train.shape[0], thetaAll_train.shape[1], 1])
)

# Separate the data set
# trainDataSet, testDataSet = torch.utils.data.random_split(AllData, [trainSetLen, testSetLen])
# trainDataSet = torch.utils.data.Subset(AllData, range(0, trainSetLen))
testDataSet = torch.utils.data.Subset(AllData, range(trainSetLen, testSetLen + trainSetLen))
print('Training data set length: ', len(trainDataSet))
print('Testing data set length: ', len(testDataSet))

# Training data loader
training_batch_size = 1024
trainDataLoader = DataLoader(
    trainDataSet,
    batch_size = training_batch_size,
    shuffle = True,
#    num_workers = 16,
    collate_fn = None,
    pin_memory = False,
)

# Testing data loader
testing_batch_size = 256
testDataLoader = DataLoader(
    testDataSet,
    batch_size = testing_batch_size,
    shuffle = True,
#    num_workers = 16,
    collate_fn = None,
    pin_memory = False,
)
# Out:
# XAll shape:  torch.Size([10000, 1000, 3])
# Training data set length:  40000
# Testing data set length:  2000

# %%
# Function train1Epoch
def train1Epoch(dataloader, loss_fn, model, optimizer):
    r"""
        Inputs: # --------------------------------------------------------------------------------------------
            dataloader: training data set loader
            loss_fn: loss function
            model: the RNN model being trained
            optimizer: handle to the optimizer
            NMultiFlag: if or not to duplicate the sequences by multiply N(t) with a constant
        Outputs: # -------------------------------------------------------------------------------------------
            loss: Training loss at the current data set
    
    """
    losses = []
    # multis = [1., 2., 4., 8., 16.]
    for idx, (X, theta, tau) in enumerate(dataloader):
        # Arrangement of X [N, logV, s]
#         # DEBUG LINES
#         print('X shape: ', X.shape)
#         print('theta shape: ', theta.shape)
#         print('tau shape: ', tau.shape)
        # XMulti = torch.cat([X * torch.tensor([[[x, 1., 1.]]]) for x in multis], 0)
        # tauMulti = torch.cat([tau * torch.tensor([[[x]]]) for x in multis], 0)
        optimizer.zero_grad()
        # out, Hs = model(XMulti)
        # loss = loss_fn(tauMulti, out)
        out, Hs = model(X)
        loss = loss_fn(tau, out)
        
#         # DEBUG LINES
#         print('loss of batch ', idx, ': ', loss)
        
        loss.backward()
        optimizer.step()
        losses.append(loss * X.shape[0])
    
    # Return the avg loss for each sequence
    return sum(losses) / len(dataloader.dataset)


# Function evaluate test loss
def evaluateTestLoss(dataloader, loss_fn, model):
    r"""
        Inputs: # --------------------------------------------------------------------------------------------
            dataloader: testing data set loader
            loss_fn: loss function
            model: the RNN model being trained
            
        Outputs: # -------------------------------------------------------------------------------------------
            loss: Testing loss at the current data set
    
    """
    losses = []
    for idx, (X, theta, tau) in enumerate(dataloader):
        out, Hs = model(X)
        loss = loss_fn(tau, out)
        losses.append(loss * X.shape[0])
    
    # Return the avg loss for each sequence
    return sum(losses) / len(dataloader.dataset)

# %%
import time
# Train for 100 epochs
model_save_path = './data/model_synDataUnReg_1019_seq3_hiddenDim1_NMulti.pth'
loss_save_path = './data/loss_synDataUnReg_1019_seq3_hiddenDim1_NMulti.pt'
loss_history_train = []
loss_history_test = []

# Number of epochs
n_epochs = 100
output_freq = 1

# Initialize the RNN 
model = RSRNN(n_layers=1, isGRU = False)

# Learning rate
learning_rate = 1.0e-3

# Optimizer SGD
import torch.optim as optim
optimizer = optim.SGD(model.parameters(), lr = learning_rate, momentum = 0.9)


for epoch in range(n_epochs):
    st_time = time.time()
    
    # Train for 1 epoch
    train_loss = train1Epoch(trainDataLoader, AccessibleL2Loss, model, optimizer)
    loss_history_train.append(train_loss.item())
    
    # Track training time
    epoch_time = time.time() - st_time
    
    # Evaluate test loss
    test_loss = evaluateTestLoss(testDataLoader, AccessibleL2Loss, model)
    loss_history_test.append(test_loss.item())
    
    # Print out information
    if epoch % output_freq == 0:
        print("-"*20, " Epoch ", epoch, "-"*20)
        print("Training loss: ", train_loss)
        print("Testing loss: ", test_loss)
        print("Training time for this epoch: ", epoch_time)
        print('\n')

# Save the trained model
LossObj = {'train_loss' : loss_history_train, 'test_loss' : loss_history_test}
torch.save(model, model_save_path)
torch.save(LossObj, loss_save_path)
# Out:
# --------------------  Epoch  0 --------------------
# Training loss:  tensor(3.7555, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(1.1986, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.015190362930298
#
#
# --------------------  Epoch  1 --------------------
# Training loss:  tensor(1.3995, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(1.0895, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.463472366333008
#
#
# --------------------  Epoch  2 --------------------
# Training loss:  tensor(1.1869, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.9392, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.277638912200928
#
#
# --------------------  Epoch  3 --------------------
# Training loss:  tensor(1.0706, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.8052, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.484334230422974
#
#
# --------------------  Epoch  4 --------------------
# Training loss:  tensor(0.9615, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.6820, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.571006774902344
#
#
# --------------------  Epoch  5 --------------------
# Training loss:  tensor(0.8719, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.5809, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.945028066635132
#
#
# --------------------  Epoch  6 --------------------
# Training loss:  tensor(0.8164, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.5343, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.196832180023193
#
#
# --------------------  Epoch  7 --------------------
# Training loss:  tensor(0.7819, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.4644, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.531529903411865
#
#
# --------------------  Epoch  8 --------------------
# Training loss:  tensor(0.7533, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.4546, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.248554944992065
#
#
# --------------------  Epoch  9 --------------------
# Training loss:  tensor(0.7266, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.4046, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.277424812316895
#
#
# --------------------  Epoch  10 --------------------
# Training loss:  tensor(0.6932, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.3661, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.534598350524902
#
#
# --------------------  Epoch  11 --------------------
# Training loss:  tensor(0.6573, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.3383, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.74753475189209
#
#
# --------------------  Epoch  12 --------------------
# Training loss:  tensor(0.6129, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2989, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.839611768722534
#
#
# --------------------  Epoch  13 --------------------
# Training loss:  tensor(0.5587, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2602, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.421438455581665
#
#
# --------------------  Epoch  14 --------------------
# Training loss:  tensor(0.5067, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2294, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.63795256614685
#
#
# --------------------  Epoch  15 --------------------
# Training loss:  tensor(0.4707, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1607, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.62878441810608
#
#
# --------------------  Epoch  16 --------------------
# Training loss:  tensor(0.4275, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1437, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.97030735015869
#
#
# --------------------  Epoch  17 --------------------
# Training loss:  tensor(0.4356, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1688, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.110717296600342
#
#
# --------------------  Epoch  18 --------------------
# Training loss:  tensor(0.4321, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2604, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.197402477264404
#
#
# --------------------  Epoch  19 --------------------
# Training loss:  tensor(0.4259, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1120, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.97735285758972
#
#
# --------------------  Epoch  20 --------------------
# Training loss:  tensor(0.8777, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.5341, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.380916833877563
#
#
# --------------------  Epoch  21 --------------------
# Training loss:  tensor(0.6406, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1551, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.907228708267212
#
#
# --------------------  Epoch  22 --------------------
# Training loss:  tensor(0.3947, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1264, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.15951418876648
#
#
# --------------------  Epoch  23 --------------------
# Training loss:  tensor(0.3423, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1259, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.57118320465088
#
#
# --------------------  Epoch  24 --------------------
# Training loss:  tensor(0.3454, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1542, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.8292875289917
#
#
# --------------------  Epoch  25 --------------------
# Training loss:  tensor(0.3539, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1209, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.814739227294922
#
#
# --------------------  Epoch  26 --------------------
# Training loss:  tensor(0.3478, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1046, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.827340126037598
#
#
# --------------------  Epoch  27 --------------------
# Training loss:  tensor(0.3240, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1569, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.002331733703613
#
#
# --------------------  Epoch  28 --------------------
# Training loss:  tensor(0.4900, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1451, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.062686443328857
#
#
# --------------------  Epoch  29 --------------------
# Training loss:  tensor(0.6605, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2060, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.062686443328857
#
#
# --------------------  Epoch  30 --------------------
# Training loss:  tensor(0.2899, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1498, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.217350721359253
#
#
# --------------------  Epoch  31 --------------------
# Training loss:  tensor(0.2881, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1081, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.26301670074463
#
#
# --------------------  Epoch  32 --------------------
# Training loss:  tensor(0.2942, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1140, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.299729585647583
#
#
# --------------------  Epoch  33 --------------------
# Training loss:  tensor(0.2963, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0703, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.407694816589355
#
#
# --------------------  Epoch  34 --------------------
# Training loss:  tensor(0.2912, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1945, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.97345519065857
# --------------------  Epoch  35 --------------------
# Training loss:  tensor(0.4030, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2310, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.097238302230835
#
#
# --------------------  Epoch  36 --------------------
# Training loss:  tensor(0.5043, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.3033, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.023142099380493
#
#
# --------------------  Epoch  37 --------------------
# Training loss:  tensor(0.4690, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1572, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.7598659992218
#
#
# --------------------  Epoch  38 --------------------
# Training loss:  tensor(0.4349, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2365, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.193490982055664
#
#
# --------------------  Epoch  39 --------------------
# Training loss:  tensor(0.4292, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1793, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.58329701423645
#
#
# --------------------  Epoch  40 --------------------
# Training loss:  tensor(0.4106, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1386, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.397672414779663
#
#
# --------------------  Epoch  41 --------------------
# Training loss:  tensor(0.3980, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1607, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.91550064086914
#
#
# --------------------  Epoch  42 --------------------
# Training loss:  tensor(0.3901, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1441, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.3210608959198
#
#
# --------------------  Epoch  43 --------------------
# Training loss:  tensor(0.3819, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1475, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.337487936019897
#
#
# --------------------  Epoch  44 --------------------
# Training loss:  tensor(0.3605, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.2433, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.46081280708313
#
#
# --------------------  Epoch  45 --------------------
# Training loss:  tensor(0.3732, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1889, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.55364203453064
#
#
# --------------------  Epoch  46 --------------------
# Training loss:  tensor(0.3699, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1673, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.245551824569702
#
#
# --------------------  Epoch  47 --------------------
# Training loss:  tensor(0.3621, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1989, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.373929023742676
#
#
# --------------------  Epoch  48 --------------------
# Training loss:  tensor(0.3516, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1905, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.134305953979492
#
#
# --------------------  Epoch  49 --------------------
# Training loss:  tensor(0.3516, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1573, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.580202102661133
#
#
# --------------------  Epoch  50 --------------------
# Training loss:  tensor(0.3476, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1369, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.814844608306885
#
#
# --------------------  Epoch  51 --------------------
# Training loss:  tensor(0.3434, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1187, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.120248794555664
#
#
# --------------------  Epoch  52 --------------------
# Training loss:  tensor(0.3388, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1216, grad_fn=<DivBackward0>)
# Training time for this epoch:  22.69141912460327
#
#
# --------------------  Epoch  53 --------------------
# Training loss:  tensor(0.3316, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1062, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.680558681488037
#
#
# --------------------  Epoch  54 --------------------
# Training loss:  tensor(0.3320, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1318, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.160045623779297
#
#
# --------------------  Epoch  55 --------------------
# Training loss:  tensor(0.3306, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1278, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.399388790130615
#
#
# --------------------  Epoch  56 --------------------
# Training loss:  tensor(0.3252, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1790, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.867477893829346
#
#
# --------------------  Epoch  57 --------------------
# Training loss:  tensor(0.3280, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1722, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.78237271308899
#
#
# --------------------  Epoch  58 --------------------
# Training loss:  tensor(0.3252, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1119, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.70252799987793
#
#
# --------------------  Epoch  59 --------------------
# Training loss:  tensor(0.3199, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1163, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.882088899612427
#
#
# --------------------  Epoch  60 --------------------
# Training loss:  tensor(0.3157, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1350, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.64517378807068
#
#
# --------------------  Epoch  61 --------------------
# Training loss:  tensor(0.3151, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1113, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.372941255569458
#
#
# --------------------  Epoch  62 --------------------
# Training loss:  tensor(0.3075, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1404, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.767009019851685
#
#
# --------------------  Epoch  63 --------------------
# Training loss:  tensor(0.3129, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1406, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.1135196685791
#
#
# --------------------  Epoch  64 --------------------
# Training loss:  tensor(0.3088, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1581, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.8806312084198
#
#
# --------------------  Epoch  65 --------------------
# Training loss:  tensor(0.3025, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1419, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.827003240585327
#
#
# --------------------  Epoch  66 --------------------
# Training loss:  tensor(0.3046, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1167, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.194992303848267
#
#
# --------------------  Epoch  67 --------------------
# Training loss:  tensor(0.3012, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1415, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.879812479019165
#
#
# --------------------  Epoch  68 --------------------
# Training loss:  tensor(0.3027, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1141, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.843138456344604
#
#
# --------------------  Epoch  69 --------------------
# Training loss:  tensor(0.2978, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1428, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.165674686431885
# --------------------  Epoch  70 --------------------
# Training loss:  tensor(0.2959, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0955, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.223539113998413
#
#
# --------------------  Epoch  71 --------------------
# Training loss:  tensor(0.2931, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1187, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.65820837020874
#
#
# --------------------  Epoch  72 --------------------
# Training loss:  tensor(0.2923, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1035, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.987560749053955
#
#
# --------------------  Epoch  73 --------------------
# Training loss:  tensor(0.2883, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1158, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.903402090072632
#
#
# --------------------  Epoch  74 --------------------
# Training loss:  tensor(0.2864, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1316, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.183363914489746
#
#
# --------------------  Epoch  75 --------------------
# Training loss:  tensor(0.2867, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1020, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.81285786628723
#
#
# --------------------  Epoch  76 --------------------
# Training loss:  tensor(0.2825, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1251, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.242820024490356
#
#
# --------------------  Epoch  77 --------------------
# Training loss:  tensor(0.2832, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1045, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.038182020187378
#
#
# --------------------  Epoch  78 --------------------
# Training loss:  tensor(0.2776, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1507, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.04809331893921
#
#
# --------------------  Epoch  79 --------------------
# Training loss:  tensor(0.2911, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0617, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.96657919883728
#
#
# --------------------  Epoch  80 --------------------
# Training loss:  tensor(0.2746, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0883, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.924543857574463
#
#
# --------------------  Epoch  81 --------------------
# Training loss:  tensor(0.2768, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1204, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.399104118347168
#
#
# --------------------  Epoch  82 --------------------
# Training loss:  tensor(0.2714, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1068, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.09498643875122
#
#
# --------------------  Epoch  83 --------------------
# Training loss:  tensor(0.2722, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1383, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.469215631484985
#
#
# --------------------  Epoch  84 --------------------
# Training loss:  tensor(0.2730, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1430, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.204700708389282
#
#
# --------------------  Epoch  85 --------------------
# Training loss:  tensor(0.2733, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1432, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.173315048217773
#
#
# --------------------  Epoch  86 --------------------
# Training loss:  tensor(0.2718, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1627, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.42391872406006
#
#
# --------------------  Epoch  87 --------------------
# Training loss:  tensor(0.2698, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1512, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.19717049598694
#
#
# --------------------  Epoch  88 --------------------
# Training loss:  tensor(0.2669, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1125, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.281204223632812
#
#
# --------------------  Epoch  89 --------------------
# Training loss:  tensor(0.2677, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1536, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.3621346950531
#
#
# --------------------  Epoch  90 --------------------
# Training loss:  tensor(0.1802, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0622, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.511428356170654
#
#
# --------------------  Epoch  91 --------------------
# Training loss:  tensor(0.1782, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0568, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.0583016872406
#
#
# --------------------  Epoch  92 --------------------
# Training loss:  tensor(0.2657, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1179, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.04243564605713
#
#
# --------------------  Epoch  93 --------------------
# Training loss:  tensor(0.2418, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0867, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.203291177749634
#
#
# --------------------  Epoch  94 --------------------
# Training loss:  tensor(0.2704, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0867, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.082761526107788
#
#
# --------------------  Epoch  95 --------------------
# Training loss:  tensor(0.2671, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0706, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.83518123626709
#
#
# --------------------  Epoch  96 --------------------
# Training loss:  tensor(0.2602, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.1361, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.102280855178833
#
#
# --------------------  Epoch  97 --------------------
# Training loss:  tensor(0.2622, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0908, grad_fn=<DivBackward0>)
# Training time for this epoch:  23.723029851913452
#
#
# --------------------  Epoch  98 --------------------
# Training loss:  tensor(0.2545, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0685, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.703680515289307
#
#
# --------------------  Epoch  99 --------------------
# Training loss:  tensor(0.2695, dtype=torch.float64, grad_fn=<DivBackward0>)
# Testing loss:  tensor(0.0959, grad_fn=<DivBackward0>)
# Training time for this epoch:  24.176440477371216

# %% [markdown]
# # Load model, plot predictions

# %%
# Paths
model_save_path = './data/model_synDataUnReg_1019_seq3_hiddenDim1_NMulti.pth'
loss_save_path = './data/loss_synDataUnReg_1019_seq3_hiddenDim1_NMulti.pt'
trainedModel = torch.load(model_save_path)
loadedHistory = torch.load(loss_save_path)

loss_history_train = loadedHistory['train_loss']
loss_history_test = loadedHistory['test_loss']

# Plot loss-epoch curve
plt.plot(range(1, 1 + len(loss_history_train)), loss_history_train, linewidth = 2.0)
plt.plot(range(1, 1 + len(loss_history_test)), loss_history_test, linewidth = 2.0)
plt.grid()

plt.xlabel('Epoch', fontsize = 20)
plt.ylabel('Loss', fontsize = 20)
plt.ylim([0, 1])
plt.title('Training with 1 hidden variable', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Training with 1 hidden variable')

# %%
# Plot the slip rate, friction coefficient vs. time for sequence [idx]
idx = 3
f, axs = plt.subplots(1, 2, figsize = (15, 7))
XAll_test = XAll[testDataSet.indices].float()
VAll_test = VAll[testDataSet.indices].float()
thetaAll_test = thetaAll[testDataSet.indices].float()
NAll_test = NAll[testDataSet.indices].float()
sAll_test = sAll[testDataSet.indices].float()
tauAll_test_true = tauAll[testDataSet.indices].float()

# XAll_test = XAll[testDataSet.indices]
# VAll_test = VAll[testDataSet.indices]
# thetaAll_test = thetaAll[testDataSet.indices]
# NAll_test = NAll[testDataSet.indices]
# sAll_test = sAll[testDataSet.indices]
# tauAll_test_true = tauAll[testDataSet.indices]

tauAll_test_pred, hiddenAll_test_pred = trainedModel(XAll_test)
tauAll_test_pred = tauAll_test_pred.reshape([tauAll_test_pred.shape[0], XAll_test.shape[1]]).detach()
fcoef_test_true = tauAll_test_true / NAll_test
fcoef_test_pred = tauAll_test_pred / NAll_test

# Plot V(t)
axs[0].semilogy(1e6 * t, VAll_test[idx, :], linewidth=2.0)
axs[0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0].set_ylabel('Slip rate $V(t)\  \mathrm{[m/s]}$', fontsize=20)
# axs[0].set_ylim([1e-6, 1e2])
axs[0].grid()
                
# Plot fcoef(t)
# axs[1].scatter(1e6 * t, fcoef_test_true[idx, :])
axs[1].plot(1e6 * t, fcoef_test_true[idx, :], linewidth=3.0)
axs[1].plot(1e6 * t, fcoef_test_pred[idx, :], linewidth=2.0)
axs[1].legend(['True', 'Pred'], loc = 'best', fontsize = 20)
axs[1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1].set_ylabel('Friction coef', fontsize=20)
axs[1].set_ylim([0, 1])
axs[1].grid()

f.suptitle("The " + str(idx) + "th sequence", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'The 3th sequence')

# %%
# Plot the V(t), N(t), theta(t), tau(t) for sequence [idx]
f, axs = plt.subplots(2, 2, figsize = (15, 15))

# Plot V(t)
axs[0][0].semilogy(1e6 * t, VAll_test[idx, :], linewidth=2.0)
axs[0][0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0][0].set_ylabel('Slip rate $V(t)\  \mathrm{[m/s]}$', fontsize=20)
axs[0][0].set_ylim([1e-15, 1e2])
axs[0][0].grid()

# Plot N(t)
axs[0][1].plot(1e6 * t, NAll_test[idx, :], linewidth=2.0)
axs[0][1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0][1].set_ylabel('Normal traction $N(t)\ \mathrm{[MPa]}$', fontsize=20)
axs[0][1].set_ylim([0, 15])
axs[0][1].grid()
                
# Plot theta(t)
axs[1][0].semilogy(1e6 * t, thetaAll_test[idx, :], linewidth=3.0)
axs[1][0].semilogy(1e6 * t, 1.e-6 / VAll_test[idx, :], linewidth=2.0)
axs[1][0].legend(['True', 'steady-state'], loc='best', fontsize = 20)
axs[1][0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1][0].set_ylabel('State Variable $\\theta(t)\ \mathrm{[s]}$', fontsize=20)
axs[1][0].grid()
                
# Plot \tau(t)
axs[1][1].plot(1e6 * t, tauAll_test_true[idx, :], linewidth=3.0)
axs[1][1].plot(1e6 * t, tauAll_test_pred[idx, :], linewidth=2.0)
axs[1][1].legend(['True', 'Pred'], loc = 'best', fontsize = 20)
axs[1][1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1][1].set_ylabel('Shear traction $\\tau(t)\ \mathrm{[MPa]}$', fontsize=20)
axs[1][1].set_ylim([0, 12])
axs[1][1].grid()

f.suptitle("The " + str(idx) + "th sequence", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'The 3th sequence')

# %% [markdown]
# # Test on a real slip-rate-sequence obtained from FEM simulation

# %%
# # Load from file
# filename = "./data/realDatas1018.pt"
# loaded = torch.load(filename)
# indexes = loaded['indexes']
# tauReal = loaded['tau'][indexes]
# NrealTest = loaded['N'][indexes]
# VrealTest = loaded['V'][indexes]
# sReal = loaded['S'][indexes]
# thetaReal = loaded['theta'][indexes]
# t = loaded['t']

# Load un-regularized sequences
filename = "./data/realDatas1018.pt"
loaded = torch.load(filename)
tauReal = loaded['tauUnReg']
NrealTest = loaded['N']
VrealTest = loaded['V']
sReal = loaded['SUnReg']
thetaReal = loaded['thetaAllUnReg']
t = loaded['t']
RSparams = RateStateParams()

print('-' * 20, 'Data Info', '-' * 20)
print('Number of data lines: ', NrealTest.shape[0])
print('Number of time grid points: ', NrealTest.shape[1])
# Out:
# -------------------- Data Info --------------------
# Number of data lines:  18685
# Number of time grid points:  1000

# %%
# Get RNN prediction from trained model on the same test data set
model_save_path = './data/model_synDataUnReg_1019_seq3_hiddenDim1_NMulti.pth'
trainedModel = torch.load(model_save_path)
XReal = torch.stack([NrealTest, torch.log10(VrealTest), sReal], 2).float()
tauReal_pred, hiddenReal_pred = trainedModel(XReal)
tauReal_pred = tauReal_pred.reshape([tauReal_pred.shape[0], tauReal_pred.shape[1]]).detach()
testSt = 14948

# %% [markdown]
# # Performance on real data sets:

# %%
# Plot the slip rate, friction coefficient vs. time for sequence [idx]
idx = 1200 + testSt
f, axs = plt.subplots(1, 2, figsize = (15, 7))

# Plot V(t)
axs[0].semilogy(1e6 * t, VrealTest[idx, :], linewidth=2.0)
axs[0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0].set_ylabel('Slip rate $V(t)\  \mathrm{[m/s]}$', fontsize=20)
axs[0].set_ylim([1e-15, 1e2])
axs[0].grid()

fcoef_real_true = tauReal / NrealTest
fcoef_real_pred = tauReal_pred / NrealTest
                
# Plot fcoef(t)
axs[1].plot(1e6 * t, fcoef_real_true[idx, :], linewidth=3.0)
axs[1].plot(1e6 * t, fcoef_real_pred[idx, :], linewidth=2.0)
axs[1].legend(['True', 'Pred'], loc = 'best', fontsize = 20)
axs[1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1].set_ylabel('Friction coef', fontsize=20)
axs[1].set_ylim([0, 1])
axs[1].grid()

f.suptitle("The " + str(idx) + "th sequence", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'The 16148th sequence')

# %%
# Plot the V(t), N(t), theta(t), tau(t) for sequence [idx]
idx = 1200 + testSt
f, axs = plt.subplots(2, 2, figsize = (15, 15))

# Plot V(t)
axs[0][0].semilogy(1e6 * t, VrealTest[idx, :], linewidth=2.0)
axs[0][0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0][0].set_ylabel('Slip rate $V(t)\  \mathrm{[m/s]}$', fontsize=20)
axs[0][0].set_ylim([1e-15, 1e2])
axs[0][0].grid()

# Plot N(t)
axs[0][1].plot(1e6 * t, NrealTest[idx, :], linewidth=2.0)
axs[0][1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0][1].set_ylabel('Normal traction $N(t)\ \mathrm{[MPa]}$', fontsize=20)
axs[0][1].set_ylim([0, 15])
axs[0][1].grid()
                
# Plot theta(t)
axs[1][0].semilogy(1e6 * t, thetaReal[idx, :], linewidth=3.0)
axs[1][0].semilogy(1e6 * t, 1.e-6 / VrealTest[idx, :], linewidth=2.0)
axs[1][0].legend(['True', 'steady-state'], loc='best', fontsize = 20)
axs[1][0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1][0].set_ylabel('State Variable $\\theta(t)\ \mathrm{[s]}$', fontsize=20)
axs[1][0].grid()
                
# Plot \tau(t)
axs[1][1].plot(1e6 * t, tauReal[idx, :], linewidth=3.0)
axs[1][1].plot(1e6 * t, tauReal_pred[idx, :], linewidth=2.0)
axs[1][1].legend(['True', 'Pred'], loc = 'best', fontsize = 20)
axs[1][1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1][1].set_ylabel('Shear traction $\\tau(t)\ \mathrm{[MPa]}$', fontsize=20)
axs[1][1].set_ylim([0, 12])
axs[1][1].grid()

f.suptitle("The " + str(idx) + "th sequence", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'The 16148th sequence')

# %% [markdown]
# # Test whether $\tau(t)$ is proportional to $N(t)$, on SYNTHETIC data set

# %%
# Specify the index in the test data set to start from
idx = 100

# XAll test is organized as [N, logV, Slip]
X = XAll_test[idx, :, :]
nOfTimeSteps = X.shape[0]
nOfFeatures = X.shape[1]

# Multplications on N
multis = torch.tensor([0.5, 1.0, 1.5, 2.0]).reshape([-1, 1])
multis = torch.cat([multis, torch.ones([multis.shape[0], 1]), torch.ones([multis.shape[0], 1])], 1)
multis = multis.reshape([multis.shape[0], 1, multis.shape[1]])
multis = multis.expand([-1, nOfTimeSteps, -1])
X = X.reshape([1, X.shape[0], X.shape[1]])
X = X * multis

# Make predictions
NX = X[:, :, 0]
tauX, hiddenX = trainedModel(X)
tauX = tauX.reshape([tauX.shape[0], tauX.shape[1]])

# %%
# Plot friction coefficient vs. time for different N/N_0
NByN0 = [1, 2, 3, 4]
# NByN0 = [1]
# Plot the slip rate, friction coefficient vs. time for sequence [idx]
f, axs = plt.subplots(1, 2, figsize = (15, 7))

# Find the friction coefficient
tauXidxs = [x - 1 for x in NByN0]
fric_multis = tauX[tauXidxs] / NX[tauXidxs]
fric_multis = fric_multis.detach()

# Plot V(t)
axs[0].semilogy(1e6 * t, VAll_test[idx, :], linewidth=2.0)
axs[0].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[0].set_ylabel('Slip rate $\dot{\delta}(t)\  \mathrm{[m/s]}$', fontsize=20)
# axs[0].set_ylim([1e-6, 1e2])
axs[0].grid()
                
# Plot the true values of fcoef(t)
# axs[1].scatter(1e6 * t, fcoef_test_true[idx, :])
axs[1].plot(1e6 * t, fcoef_test_true[idx, :], linewidth = 3.5)
lineWidths = torch.linspace(3.0, 1.0, len(NByN0))
legStr = ["True"]

for i in range(len(NByN0)):
    axs[1].plot(1e6 * t, fric_multis[i, :], linewidth = lineWidths[i])
    legStr.append("$\\sigma / \\sigma_0$ = " + str(multis[tauXidxs[i], 0, 0].item()))
    

axs[1].legend(legStr, loc = 'best', fontsize = 20)
axs[1].set_xlabel('Time [$\mu$ s]', fontsize=20)
axs[1].set_ylabel('Friction coef', fontsize=20)
axs[1].set_ylim([0.2, 1.5])
axs[1].grid()

f.suptitle("The " + str(idx) + "th sequence", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'The 100th sequence')
